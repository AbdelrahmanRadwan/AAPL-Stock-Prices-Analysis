# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import plotly.figure_factory as ff

import plotly.plotly as py
from plotly.graph_objs import *

# %%
csv_file_i = "../DataSet/Dataset.csv"

_df = pd.read_csv(csv_file_i)

df = pd.DataFrame(_df, 
        index=pd.date_range('1/1/2013', periods=50))
df = df.cumsum()
df.plot(style='.-')
