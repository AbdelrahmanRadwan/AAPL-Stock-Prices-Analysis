# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
csv_file_i = "../DataSet/Dataset.csv"
#load the input in a data frame
df = pd.read_csv(csv_file_i)

df[['Open','Date']].plot()

df[['Close','Date']].plot()

df[['Open','Close']].plot()

df[['same_day_delta','Date']].plot()

df.hist(column='same_day_delta')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbec7465b50>]],
#       dtype=object)
